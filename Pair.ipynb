# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/ECE570/FinalProject/RegluarLRNN-master')
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Arithmetic.ipynb     cycle.csv	  cycle.py		pair.csv  Pair.ipynb  __pycache__
# arith_sequences.csv  Cycle.ipynb  DataGeneration.ipynb	Pair.csv  pair.py     README.md

# %%
import torch
import torch.nn as nn
import math

import torch
import torch.nn as nn
import argparse

# !pip install torch --upgrade
# from torch._dynamo.utils import CompileProfiler
# prof = CompileProfiler()
from torch.utils.data import DataLoader, TensorDataset
torch.set_float32_matmul_precision('high')

from google.colab import files
import csv
#files.download('/content/arith_sequences.csv')

import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
import torch.nn.functional as F
import math

# %%
class BlockModel(nn.Module):
    def __init__(self, M = 2, emb_dim=8, block_dim=2):
        super().__init__()

        self.M = M
        self.emb_dim = emb_dim
        self.block_dim = block_dim
        h = emb_dim//block_dim

        self.gen_block = nn.Sequential(
                            nn.Linear(emb_dim, emb_dim*block_dim),
                            nn.ReLU(),
                            nn.Linear(emb_dim*block_dim, emb_dim*block_dim),
                            )

        self.gen_value = nn.Sequential(
                            nn.Linear(emb_dim, emb_dim),
                            nn.ReLU(),
                            nn.Linear(emb_dim, emb_dim),
                            )

        self.a0 = nn.Parameter( torch.randn(1, h, block_dim) )

    def compute_hidden_state(self, input_data):
        batch_size = input_data.size(0)
        seq_length = input_data.size(1)
        num_blocks = self.emb_dim // self.block_dim  # Calculate the number of blocks

        # Generate blocks and reshape for further operations
        reshaped_blocks = self.gen_block(input_data)
        reshaped_blocks = reshaped_blocks.view(batch_size, seq_length, num_blocks, self.block_dim, self.block_dim)

        # Normalize the blocks by subtracting the mean and normalizing the scale
        block_means = reshaped_blocks.mean(dim=-2, keepdim=True)
        normalized_blocks = reshaped_blocks - block_means
        block_norms = normalized_blocks.norm(dim=-2, p=1.2, keepdim=True)
        max_norms = block_norms.max(dim=-1, keepdim=True)[0]
        normalized_blocks = normalized_blocks / max_norms

        # Generate values and reshape accordingly
        generated_values = self.gen_value(input_data).view(batch_size, seq_length, num_blocks, self.block_dim)

        # Initialize the hidden state using the parameter a0 expanded to match the batch size
        current_state = self.a0.expand(batch_size, -1, -1)  # Shape: (batch_size, num_blocks, block_dim)
        sequence_hidden_states = []  # Store all hidden states for concatenation

        # Iterate through the sequence
        for t in range(seq_length):
            # Compute the new hidden state using einsum for matrix multiplication
            updated_state = torch.einsum('bnij,bnj->bni', normalized_blocks[:, t], current_state)
            updated_state += generated_values[:, t]
            sequence_hidden_states.append(updated_state.view(batch_size, 1, self.emb_dim))  # Append the reshaped state

        # Concatenate all hidden states across the sequence dimension
        final_hidden_states = torch.cat(sequence_hidden_states, dim=1)

        return final_hidden_states



    def get_hidden_with_v_and_pscan(self, input_data):
        def process_groups(input_tensor, matrix_set):
            # Compute the split size for reshaping
            split_size = matrix_set.shape[2] * 2
            # Split the reshaped input into two parts
            reshaped_input = input_tensor.view(batch_size, padded_length // split_size, split_size, num_blocks, -1)
            first_half, second_half = reshaped_input[:, :, :split_size // 2], reshaped_input[:, :, split_size // 2:]
            # Ensure that the matrix set has the correct shape for this operation
            assert matrix_set.shape[1] % 2 == 1, 'The second dimension of matrix_set must be 2^k - 1 for k >= 1'
            # Select alternating coefficients and remaining matrices
            coefficient_matrices = matrix_set[:, ::2]
            residual_matrices = matrix_set[:, 1::2]

            # Perform einsum to compute products for residuals
            product_result = torch.einsum('bnchij,bnhjk->bnchik', coefficient_matrices[:, 1:], residual_matrices[:, :, -1])
            # Concatenate residual matrices with product results
            updated_residuals = torch.cat([residual_matrices, product_result], dim=2)
            # Update the second half of the input tensor using the coefficient matrices and the last part of the first half
            second_half += torch.einsum('bnchij,bnhj->bnchi', coefficient_matrices, first_half[:, :, -1])
            # Combine both halves back together
            final_result = torch.cat([first_half, second_half], dim=2)
            return final_result, updated_residuals


        batch_size = input_data.size(0)
        seq_length = input_data.size(1)
        num_blocks = self.emb_dim // self.block_dim  # Calculate the number of blocks

        # Generate blocks and reshape for further operations
        reshaped_blocks = self.gen_block(input_data)
        reshaped_blocks = reshaped_blocks.view(batch_size, seq_length, num_blocks, self.block_dim, self.block_dim)

        # Normalize the blocks by subtracting the mean and normalizing the scale
        block_means = reshaped_blocks.mean(dim=-2, keepdim=True)
        normalized_blocks = reshaped_blocks - block_means
        block_norms = normalized_blocks.norm(dim=-2, p=1.2, keepdim=True)
        max_norms = block_norms.max(dim=-1, keepdim=True)[0]
        normalized_blocks = normalized_blocks / max_norms

        # Generate values and reshape accordingly
        generated_values = self.gen_value(input_data).view(batch_size, seq_length, num_blocks, self.block_dim)

        # Calculate the next power of 2 greater than or equal to seq_length + 1
        log2_length = int(math.ceil(math.log2(seq_length + 1)))
        padded_length = 2**log2_length  # Final length after zero padding
        num_zeros = padded_length - seq_length - 1  # Calculate how many zeros to pad

        # Concatenate the initial value (a0) with generated values, and pad with zeros
        expanded_values = torch.cat([self.a0.expand(batch_size, -1, -1)[:, None, :, :], generated_values], dim=1)
        expanded_values = nn.functional.pad(expanded_values, (0, 0, 0, 0, 0, num_zeros))

        # Pad the normalized blocks and reshape for processing
        padded_blocks = nn.functional.pad(normalized_blocks, (0, 0, 0, 0, 0, 0, 0, num_zeros))[:, :, None, :, :, :]

        # Process the groups iteratively
        for _ in range(log2_length):
            aexpanded_values, padded_blocks = process_groups(expanded_values, padded_blocks)

        # Reshape and slice the result to match the original sequence length
        expanded_values = expanded_values.view(batch_size, padded_length, self.emb_dim)[:, 1:seq_length + 1]

        return expanded_values

# %%
M = 5
seq_len = 10  # Ensure seq_len is odd

def read_and_split_data(file_path, seq_len, test_size=0.2, random_state=42):
    """
    Reads the CSV file containing sequences and answers, and splits them into training and test sets.
    Ensures the correct shape for the answers based on the sequence length.
    """
    df = pd.read_csv(file_path, header=None)

    # Separate sequences and answers
    sequences = df.iloc[::2].values  # Extract every other row starting from the first (sequences)
    answers = df.iloc[1::2].values   # Extract every other row starting from the second (answers)

    # Only keep the correct number of answers ((seq_len + 1) // 2)
    correct_num_answers = (seq_len + 1) // 2
    answers = answers[:, :correct_num_answers]  # Truncate the answers to the correct size

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(sequences, answers, test_size=test_size, random_state=random_state)

    # Convert NumPy arrays to PyTorch tensors
    X_train = torch.tensor(X_train, dtype=torch.int64)
    X_test = torch.tensor(X_test, dtype=torch.int64)
    y_train = torch.tensor(y_train, dtype=torch.int64)
    y_test = torch.tensor(y_test, dtype=torch.int64)

    return X_train, X_test, y_train, y_test


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
file_path = '/content/drive/MyDrive/ECE570/FinalProject/RegluarLRNN-master/pair.csv'

# Read and split the data
X_train, X_test, y_train, y_test = read_and_split_data(file_path, seq_len, test_size=0.2)

X_train = X_train.to(device)
X_test = X_test.to(device)
y_train = y_train.to(device)
y_test = y_test.to(device)

# Check the shapes of the training and testing sets
print("Training sequences shape:", X_train.shape)
print("Test sequences shape:", X_test.shape)
print("Training answers shape:", y_train.shape)
print("Test answers shape:", y_test.shape)


# Compare types
print("CSV training sequences type:", X_train.dtype)
print("CSV training answers type:", y_train.dtype)

print("Training Data Entry: ", X_test[0])
print("Expected Output Entry: ", y_test[0])
# Out:
# Training sequences shape: torch.Size([268696, 10])
# Test sequences shape: torch.Size([67174, 10])
# Training answers shape: torch.Size([268696, 5])
# Test answers shape: torch.Size([67174, 5])
# CSV training sequences type: torch.int64
# CSV training answers type: torch.int64
# Training Data Entry:  tensor([1, 0, 3, 1, 3, 0, 1, 3, 1, 1])
# Expected Output Entry:  tensor([1, 1, 4, 0, 3])

# %%
class PairMultiBlock(nn.Module):
    def __init__(self, M = 5, emb_dim=32, block_dim=2, n_layers=1):
        super().__init__()

        self.layers = nn.ModuleList()
        self.ln = nn.ModuleList()
        self.ln_final = nn.LayerNorm(emb_dim)
        self.embedding = nn.Embedding(M, emb_dim)
        for i in range(n_layers):
            self.layers.append(BlockModel(M=M, emb_dim=emb_dim, block_dim=block_dim))
            self.ln.append( nn.LayerNorm(emb_dim) )
        self.Wo1 = nn.Linear(emb_dim, emb_dim)
        self.Wo2 = nn.Linear(emb_dim, 5)

    def forward(self, input_x):
        a = self.embedding(input_x)
        for i in range(len(self.layers)-1):
            out = self.layers[i].get_hidden_with_v_and_pscan(self.ln[i](a))
            a = out + a
        a = self.layers[-1].get_hidden_with_v_and_pscan(self.ln[-1](a))
        a = self.ln_final(a)
        return self.Wo2(self.Wo1(a).relu())

# %%
#hyperparameters
M = 5
emb_dim = 64
block_dim = 8
n_layers = 1
torch.manual_seed(1)
batch_size = 128
train_len = 40
test_len = 500
iters = 40000
lr = 2e-4
weight_decay = 0

# %%
model = PairMultiBlock(M, emb_dim, block_dim, n_layers=n_layers)
model = model.to(device)
uncompiled_model = model
model = torch.compile(model, backend='inductor')
optimizer = torch.optim.Adam(model.parameters())

# %%
# Create TensorDataset and DataLoader for mini-batch processing
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)  # Adjust batch_size as needed

test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=128)

# Fetch one batch from the train and test loaders to inspect their sizes
batch_X_train, batch_y_train = next(iter(train_loader))
batch_X_test, batch_y_test = next(iter(test_loader))

# Print the sizes of the first batch of training and test data
print(f"batch_X_train size: {batch_X_train.size()}")
print(f"batch_y_train size: {batch_y_train.size()}")
print(f"batch_X_test size: {batch_X_test.size()}")
print(f"batch_y_test size: {batch_y_test.size()}")

# Lists to store loss and accuracy for each batch
train_losses = []
test_accuracies = []

# Training loop with mini-batches
max_acc = 0.0
for epoch in range(1):  # For now we are using one epoch for simplicity
    model.train()  # Set model to training mode

    # Iterate over mini-batches
    for batch_idx, (batch_X_train, batch_y_train) in enumerate(train_loader):
        batch_X_train, batch_y_train = batch_X_train.to(device), batch_y_train.to(device)

        # Forward pass: Get model predictions for the current batch
        predictions = model(batch_X_train)[:, ::2]

        # Compute the loss
        loss = torch.nn.functional.cross_entropy(predictions.flatten(end_dim=1), batch_y_train.flatten(end_dim=1))

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Store batch loss for training
        train_losses.append(loss.item())  # Store loss for each batch

        # Evaluate after each batch (on test set)
        model.eval()  # Set model to evaluation mode
        total_correct = 0
        total_samples = 0

        with torch.no_grad():
            # Fetch one batch from the test loader
            batch_X_test, batch_y_test = next(iter(test_loader))

            # Move the batch to the appropriate device
            batch_X_test, batch_y_test = batch_X_test.to(device), batch_y_test.to(device)

            # Forward pass on the single test batch
            logits_test = model(batch_X_test)[:, -1]  # Assuming you're only interested in the last output
            pred = logits_test.argmax(dim=-1)

            # Calculate accuracy for the single batch
            correct = (pred == batch_y_test[:, -1]).float().sum()
            total_correct = correct
            total_samples = batch_X_test.size(0)

            # Calculate accuracy for this one batch
            accuracy = total_correct / total_samples


        # Calculate accuracy for the current batch
        acc = total_correct / total_samples
        test_accuracies.append(acc.item())  # Store accuracy for each batch

        if len(test_accuracies) >= 20 and all(acc == 1.0 for acc in test_accuracies[-20:]):
            print(f"Stopping early after {batch_idx + 1} batches due to 20 consecutive perfect accuracy batches.")
            break

        if batch_idx >= 1000:
            print(f"Stopping early after {batch_idx + 1} batches due to no convergence.")
            break

        # Print the loss and accuracy for each batch
        print(f"Epoch {epoch + 1}, Batch {batch_idx + 1}, Accuracy: {acc.item():.4f}, Loss: {loss.item():.4f}")

        # Track the maximum accuracy achieved
        max_acc = max(acc, max_acc)
# Out:
# batch_X_train size: torch.Size([128, 10])
# batch_y_train size: torch.Size([128, 5])
# batch_X_test size: torch.Size([128, 10])
# batch_y_test size: torch.Size([128, 5])
# Epoch 1, Batch 1, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 2, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 3, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 4, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 5, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 6, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 7, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 8, Accuracy: 0.3984, Loss: 0.0001
# Epoch 1, Batch 9, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 10, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 11, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 12, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 13, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 14, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 15, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 16, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 17, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 18, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 19, Accuracy: 0.3984, Loss: 0.0001
# Epoch 1, Batch 20, Accuracy: 0.3984, Loss: 0.0001
# Epoch 1, Batch 21, Accuracy: 0.3828, Loss: 0.0001
# Epoch 1, Batch 22, Accuracy: 0.3828, Loss: 0.0001
# Epoch 1, Batch 23, Accuracy: 0.3906, Loss: 0.0001
# Epoch 1, Batch 24, Accuracy: 0.3906, Loss: 0.0001
# Epoch 1, Batch 25, Accuracy: 0.3906, Loss: 0.0001
# Epoch 1, Batch 26, Accuracy: 0.3906, Loss: 0.0001
# Epoch 1, Batch 27, Accuracy: 0.3906, Loss: 0.0001
# Epoch 1, Batch 28, Accuracy: 0.3906, Loss: 0.0001
# Epoch 1, Batch 29, Accuracy: 0.3984, Loss: 0.0001
# Epoch 1, Batch 30, Accuracy: 0.3984, Loss: 0.0001
# Epoch 1, Batch 31, Accuracy: 0.3984, Loss: 0.0002
# Epoch 1, Batch 32, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 33, Accuracy: 0.3828, Loss: 0.0001
# Epoch 1, Batch 34, Accuracy: 0.3828, Loss: 0.0001
# Epoch 1, Batch 35, Accuracy: 0.3750, Loss: 0.0001
# Epoch 1, Batch 36, Accuracy: 0.3672, Loss: 0.0001
# Epoch 1, Batch 37, Accuracy: 0.3672, Loss: 0.0001
# Epoch 1, Batch 38, Accuracy: 0.3594, Loss: 0.0001
# Epoch 1, Batch 39, Accuracy: 0.3594, Loss: 0.0001
# Epoch 1, Batch 40, Accuracy: 0.3672, Loss: 0.0001
# Epoch 1, Batch 41, Accuracy: 0.3750, Loss: 0.0001
# Epoch 1, Batch 42, Accuracy: 0.3906, Loss: 0.0001
# Epoch 1, Batch 43, Accuracy: 0.3984, Loss: 0.0001
# Epoch 1, Batch 44, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 45, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 46, Accuracy: 0.3984, Loss: 0.0001
# Epoch 1, Batch 47, Accuracy: 0.3906, Loss: 0.0001
# Epoch 1, Batch 48, Accuracy: 0.3828, Loss: 0.0001
# Epoch 1, Batch 49, Accuracy: 0.3828, Loss: 0.0001
# Epoch 1, Batch 50, Accuracy: 0.3828, Loss: 0.0001
# Epoch 1, Batch 51, Accuracy: 0.3906, Loss: 0.0001
# Epoch 1, Batch 52, Accuracy: 0.3984, Loss: 0.0001
# Epoch 1, Batch 53, Accuracy: 0.3984, Loss: 0.0001
# Epoch 1, Batch 54, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 55, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 56, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 57, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 58, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 59, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 60, Accuracy: 0.4062, Loss: 0.0001
# Epoch 1, Batch 61, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 62, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 63, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 64, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 65, Accuracy: 0.4219, Loss: 0.0001
# Epoch 1, Batch 66, Accuracy: 0.4219, Loss: 0.0001
# Epoch 1, Batch 67, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 68, Accuracy: 0.4219, Loss: 0.0001
# Epoch 1, Batch 69, Accuracy: 0.4219, Loss: 0.0001
# Epoch 1, Batch 70, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 71, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 72, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 73, Accuracy: 0.4297, Loss: 0.0001
# Epoch 1, Batch 74, Accuracy: 0.4219, Loss: 0.0001
# Epoch 1, Batch 75, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 76, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 77, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 78, Accuracy: 0.4141, Loss: 0.0001
# Epoch 1, Batch 79, Accuracy: 0.4219, Loss: 0.0001
# Epoch 1, Batch 80, Accuracy: 0.4219, Loss: 0.0001
# Epoch 1, Batch 81, Accuracy: 0.4219, Loss: 0.0001
# Epoch 1, Batch 82, Accuracy: 0.4219, Loss: 0.0001
# Epoch 1, Batch 83, Accuracy: 0.4219, Loss: 0.0001
# Epoch 1, Batch
Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 757, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 758, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 759, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 760, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 761, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 762, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 763, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 764, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 765, Accuracy: 0.3672, Loss: 0.0000
# Epoch 1, Batch 766, Accuracy: 0.3672, Loss: 0.0000
# Epoch 1, Batch 767, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 768, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 769, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 770, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 771, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 772, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 773, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 774, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 775, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 776, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 777, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 778, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 779, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 780, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 781, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 782, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 783, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 784, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 785, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 786, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 787, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 788, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 789, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 790, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 791, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 792, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 793, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 794, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 795, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 796, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 797, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 798, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 799, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 800, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 801, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 802, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 803, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 804, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 805, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 806, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 807, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 808, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 809, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 810, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 811, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 812, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 813, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 814, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 815, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 816, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 817, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 818, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 819, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 820, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 821, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 822, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 823, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 824, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 825, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 826, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 827, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 828, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 829, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 830, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 831, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 832, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 833, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 834, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 835, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 836, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 837, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 838, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 839, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 840, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 841, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 842, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 843, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 844, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 845, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 846, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 847, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 848, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 849, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 850, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 851, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 852, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 853, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 854, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 855, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 856, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 857, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 858, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 859, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 860, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 861, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 862, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 863, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 864, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 865, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 866, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 867, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 868, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 869, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 870, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 871, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 872, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 873, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 874, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 875, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 876, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 877, Accuracy: 0.3906, Loss: 0.0001
# Epoch 1, Batch 878, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 879, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 880, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 881, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 882, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 883, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 884, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 885, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 886, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 887, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 888, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 889, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 890, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 891, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 892, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 893, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 894, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 895, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 896, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 897, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 898, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 899, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 900, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 901, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 902, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 903, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 904, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 905, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 906, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 907, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 908, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 909, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 910, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 911, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 912, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 913, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 914, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 915, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 916, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 917, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 918, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 919, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 920, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 921, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 922, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 923, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 924, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 925, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 926, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 927, Accuracy: 0.4062, Loss: 0.0000
# Epoch 1, Batch 928, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 929, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 930, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 931, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 932, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 933, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 934, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 935, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 936, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 937, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 938, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 939, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 940, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 941, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 942, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 943, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 944, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 945, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 946, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 947, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 948, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 949, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 950, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 951, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 952, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 953, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 954, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 955, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 956, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 957, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 958, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 959, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 960, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 961, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 962, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 963, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 964, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 965, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 966, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 967, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 968, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 969, Accuracy: 0.3750, Loss: 0.0001
# Epoch 1, Batch 970, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 971, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 972, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 973, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 974, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 975, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 976, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 977, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 978, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 979, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 980, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 981, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 982, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 983, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 984, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 985, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 986, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 987, Accuracy: 0.3828, Loss: 0.0000
# Epoch 1, Batch 988, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 989, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 990, Accuracy: 0.3984, Loss: 0.0000
# Epoch 1, Batch 991, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 992, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 993, Accuracy: 0.3906, Loss: 0.0000
# Epoch 1, Batch 994, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 995, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 996, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 997, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 998, Accuracy: 0.3750, Loss: 0.0001
# Epoch 1, Batch 999, Accuracy: 0.3750, Loss: 0.0000
# Epoch 1, Batch 1000, Accuracy: 0.3984, Loss: 0.0000
# Stopping early after 1001 batches due to no convergence.

# %%
import matplotlib.pyplot as plt

# Plot loss and accuracy at the end of training
print(f"train losses: {train_losses}")
print(f"test accuracies: {test_accuracies}")
print(f"max accuracy: {max_acc}")

plt.figure(figsize=(8, 5))

# Create a plot with two y-axes
fig, ax1 = plt.subplots()

# Plot training loss on the first y-axis (left)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Training Loss', color='tab:blue')
ax1.plot(train_losses, label="Training Loss", color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

#